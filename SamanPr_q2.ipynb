# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import pandas as pd
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

## Reading the Data set from google drive !!
## plz upload the CSV files to the google drive and extract the id, as exampled here, from the sharable link. 

id = '1p_Wnbp1xiWhIQnGX7qoMQF6yJ7b4y0GS'
id2 = '1Ak3ROOBGscmaBW1AAg0cQzUO6YMSExVW'


downloaded2 = drive.CreateFile({'id':id}) 
downloaded1 = drive.CreateFile({'id':id2}) 
csv_MT = 'MT_cleaned.csv'
csv_VT = 'VT_cleaned.csv'
downloaded1.GetContentFile(csv_MT)  
#df3 = pd.read_csv('Filename.csv')
#df = pd.read_excel(excel_file)
df_MT = pd.read_csv(csv_MT)

downloaded2.GetContentFile(csv_VT)  
df_VT = pd.read_csv(csv_VT)
#df_VT.head()

df_MT.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (25,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#               id state  ... search_reason            stop_outcome_raw
# 0  MT-2009-00001    MT  ...           NaN    TRAFFIC CITATION,WARNING
# 1  MT-2009-00002    MT  ...           NaN  INFFRACTION ARREST,WARNING
# 2  MT-2009-00003    MT  ...           NaN          INFFRACTION ARREST
# 3  MT-2009-00004    MT  ...           NaN          INFFRACTION ARREST
# 4  MT-2009-00005    MT  ...           NaN          INFFRACTION ARREST
#
# [5 rows x 33 columns]

# %% [markdown]
# Q2.1

# %%
df_male = df_MT[df_MT['driver_gender']=='M']
prop_21 = 1.0 *len(df_male [df_male['stop_outcome'] == 'Citation']) / len(df_male)
print('proportion_stop_male = %.3f'%prop_21)
# Out:
# proportion_stop_male = 0.471

# %% [markdown]
# Q2.2 Sorry, I do not know the meaning of `factor increase`, I even searched for it but I could find some thing that I could solve this problem.

# %% [markdown]
# Q2.3

# %%
df_stop = df_MT[df_MT['stop_outcome'] == 'Arrest']
prop_23 = 1.0*len(df_stop [df_stop['violation'] == 'Speeding']) / len(df_stop)
print('proportion_stop_speeding = %.3f'%prop_23)
# Out:
# proportion_stop_speeding = 0.413

# %% [markdown]
# Q2.4 Like Q2.2, I did not know the `factor increase` meaning.

# %% [markdown]
# Q2.5

# %%
date_min = '2010-01-01'
date_max = '2010-12-29'
df_MT['stop_date'] = pd.to_datetime(df_MT['stop_date'], format="%Y-%m-%d")
df_MT_date = df_MT [(df_MT['stop_date'] >= date_min) & (df_MT['stop_date'] < date_max)] 
df_MT_date_stopped = df_MT_date [df_MT_date['stop_outcome'] == 'Citation']
avg_manufactured = df_MT_date_stopped['vehicle_year'].str.replace("NON-", "0").str.replace("UNK", "0").dropna().astype(int).mean()
print('averaged value of years = %.3f ' %avg_manufactured)
# Out:
# averaged value of years = 1999.976

# %% [markdown]
# Q2.6

# %%
min_hour = '1:00' ; max_hour = '23:00';
df_MT['stop_time'] = pd.to_datetime(df_MT['stop_time'],format="%H:%M")
df_VT['stop_time'] = pd.to_datetime(df_VT['stop_time'],format="%H:%M")
df_MT
df_MT_time = df_MT [(df_MT['stop_time'] >= min_hour) & (df_MT['stop_time'] < max_hour)] 
df_VT_time = df_VT [(df_VT['stop_time'] >= min_hour) & (df_VT['stop_time'] < max_hour)] 


MT_time__stop_sum = df_MT_time[df_MT_time['stop_outcome'] == 'Citation'].sum(axis=1)
VT_time__stop_sum = df_VT_time[df_VT_time['stop_outcome'] == 'Citation'].sum(axis=1)
#MT_time__stop_sum

print (' total number of stops of (MT and VT) :' ,MT_time__stop_sum ,  VT_time__stop_sum)
#MT_time__stop_sum
#df_VT.head()
# Out:
#  total number of stops of (MT and VT) : Series([], dtype: float64) Series([], dtype: float64)

# %% [markdown]
# Q2.7
# I could not the area column (sq.km) in the data set (even the hight and width for computing it), but it can simply be computed by simple query `df[area].max(axis=1)`
